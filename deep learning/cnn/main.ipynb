# %%
from __future__ import annotations

import os
import random
from dataclasses import dataclass
from typing import Dict, List, Optional, Tuple
import copy
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split

import matplotlib.pyplot as plt

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
)

from torchvision import datasets, transforms
from torchvision import models as tv_models

from dataset import make_fashionmnist_loaders
from models import VGGLikeSmall, make_resnet18
from utils import RunConfig, train_model, evaluate_model, plot_losses

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(device)


def run_group(
    group_name: str,
    model_fns: Dict[str, callable],
    train_loader: DataLoader,
    val_loader: DataLoader,
    test_loader: DataLoader,
    cfg: RunConfig,
) -> "pd.DataFrame":
    """Train/eval all models in a group and return a summary table."""

    print("\n" + "=" * 90)
    print(f"Running group: {group_name}")
    print("=" * 90)

    group_results: Dict[str, Dict[str, object]] = {}
    criterion = nn.CrossEntropyLoss()

    for name, fn in model_fns.items():
        print(f"\nTraining {name}...")
        model = fn().to(device)

        optimizer = optim.Adam(
            (p for p in model.parameters() if p.requires_grad),
            lr=cfg.lr,
            weight_decay=cfg.weight_decay,
        )

        train_losses, val_losses, best_state, best_epoch = train_model(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            criterion=criterion,
            optimizer=optimizer,
            cfg=cfg,
            device=device,
        )
        model.load_state_dict(best_state)
        print(f"Selected best epoch (by dev loss): {best_epoch}")

        class_names = test_loader.dataset.classes  # FashionMNIST classes
        metrics = evaluate_model(
            model=model,
            loader=test_loader,
            device=device,
            class_names=class_names,
        )

        group_results[name] = {
            "train_loss": train_losses,
            "val_loss": val_losses,
            **metrics,
        }

        print(
            f"{name} | "
            f"acc={metrics['accuracy']:.4f} "
            f"prec(macro)={metrics['precision_macro']:.4f} "
            f"rec(macro)={metrics['recall_macro']:.4f} "
            f"f1(macro)={metrics['f1_macro']:.4f} "
            f"f1(micro)={metrics['f1_micro']:.4f}"
        )

        if metrics["report_df"] is not None:
            print("\nPer-class results on TEST (precision/recall/f1/support):")
            # print only the 10 classes rows
            print(metrics["report_df"].loc[class_names, ["precision", "recall", "f1-score", "support"]].to_string())

            out_rep = f"{group_name}_{name}_test_report.csv"
            metrics["report_df"].to_csv(out_rep, index=True)
            print(f"Saved per-class test report -> {out_rep}\n")

    plot_losses(group_name, group_results)

    rows = []
    for name, r in group_results.items():
        rows.append(
            {
                "group": group_name,
                "model": name,
                "accuracy": r["accuracy"],
                "precision_macro": r["precision_macro"],
                "recall_macro": r["recall_macro"],
                "f1_macro": r["f1_macro"],
                "precision_micro": r["precision_micro"],
                "recall_micro": r["recall_micro"],
                "f1_micro": r["f1_micro"],
                "final_train_loss": float(r["train_loss"][-1]),
                "final_val_loss": float(r["val_loss"][-1]),
            }
        )

    return pd.DataFrame(rows).sort_values(by="accuracy", ascending=False).reset_index(drop=True)


def main() -> None:
    cfg = RunConfig(
        epochs=20,
        lr=1e-3,
        weight_decay=1e-4,
        amp=True,
        max_batches_per_epoch=None,
    )

    batch_size = 128

    
    #Loaders for VGG-style (1x28x28, MNIST stats)
    
    train_loader, val_loader, test_loader = make_fashionmnist_loaders(
        batch_size=batch_size,
        img_size=28,
        channels=1,
        normalize="mnist",
        augment=False,
    )
    train_loader_aug, val_loader_aug, test_loader_aug = make_fashionmnist_loaders(
        batch_size=batch_size,
        img_size=28,
        channels=1,
        normalize="mnist",
        augment=True,
    )

    
    #Loaders for ResNet18 (3x224x224, ImageNet stats)
   
    train_loader_rn, val_loader_rn, test_loader_rn = make_fashionmnist_loaders(
        batch_size=batch_size,
        img_size=224,
        channels=3,
        normalize="imagenet",
        augment=False,
    )

    #GROUP 1: VGG-like with vs without augmentation
    
    group_1 = {
        "VGG_NoAug": lambda: VGGLikeSmall(in_channels=1, num_classes=10, use_bn=True, dropout=0.3),
        "VGG_WithAug": lambda: VGGLikeSmall(in_channels=1, num_classes=10, use_bn=True, dropout=0.3),
    }

    df_vgg_noaug = run_group(
        "01_VGG_NoAug",
        {"VGG_NoAug": group_1["VGG_NoAug"]},
        train_loader,
        val_loader,
        test_loader,
        cfg,
    )
    df_vgg_aug = run_group(
        "01_VGG_WithAug",
        {"VGG_WithAug": group_1["VGG_WithAug"]},
        train_loader_aug,
        val_loader_aug,
        test_loader_aug,
        cfg,
    )


    #GROUP 2: ResNet18 variants
    
    group_2 = {
        "ResNet18_Random": lambda: make_resnet18(num_classes=10, pretrained=False, freeze_backbone=False),
        "ResNet18_ImgNet_Frozen": lambda: make_resnet18(num_classes=10, pretrained=True, freeze_backbone=True),
        "ResNet18_ImgNet_Finetune": lambda: make_resnet18(num_classes=10, pretrained=True, freeze_backbone=False),
    }

    cfg_rn = RunConfig(
        epochs=cfg.epochs,
        lr=1e-4,
        weight_decay=cfg.weight_decay,
        amp=cfg.amp,
        max_batches_per_epoch=cfg.max_batches_per_epoch,
    )

    df_rn = run_group(
        "02_ResNet18_Variants",
        group_2,
        train_loader_rn,
        val_loader_rn,
        test_loader_rn,
        cfg_rn,
    )


    summary = pd.concat([df_vgg_noaug, df_vgg_aug, df_rn], axis=0).reset_index(drop=True)

    print("\n" + "=" * 90)
    print("Overall summary (sorted by accuracy)")
    print("=" * 90)
    print(summary.sort_values(by="accuracy", ascending=False).to_string(index=False))

    out_csv = "fashionmnist_cnn_groups_summary.csv"
    summary.to_csv(out_csv, index=False)
    print(f"\nSaved summary CSV -> {out_csv}")



if __name__ == "__main__":
    main()
# Out:
# cuda
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 9.29MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 176kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.20MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 26.5MB/s]
# FashionMNIST loaders | train=54000 val=6000 test=10000 | img_size=28 channels=1 augment=False normalize=mnist
# FashionMNIST loaders | train=54000 val=6000 test=10000 | img_size=28 channels=1 augment=True normalize=mnist
# FashionMNIST loaders | train=54000 val=6000 test=10000 | img_size=224 channels=3 augment=False normalize=imagenet
#
# ...
# Running group: 01_VGG_NoAug
# ...
#
# Training VGG_NoAug...
# Epoch 01/20 | train_loss=0.5148 val_loss=0.4151 | val_acc=0.8535 val_f1_macro=0.8502 val_f1_micro=0.8535
# Epoch 02/20 | train_loss=0.3144 val_loss=0.3059 | val_acc=0.8860 val_f1_macro=0.8883 val_f1_micro=0.8860
# Epoch 03/20 | train_loss=0.2650 val_loss=0.2575 | val_acc=0.9040 val_f1_macro=0.9027 val_f1_micro=0.9040
# ...
